# %% [markdown]
# CHAPTER -01
# MODULES, COMMENTS AND PIPS

# %%
#Write a program to print Twinkle twinkle litte Star poem in python.
print("Twinkle Twinkle Little Star,\n"
"how i wonder what you are,\n"
"what above world so high,\n"
"Like a wonder in the sky!!\n")
# Out:
# Twinkle Twinkle Little Star,
# how i wonder what you are,
# what above world so high,
# Like a wonder in the sky!!

# %%
# Use REPL and print the table of 5 using it.

# SyntaxError: invalid syntax
# >>> 5*1
# 5
# >>> 5*2
# 10
# >>> 5*#
#   File "<stdin>", line 1
#     5*#
#       ^
# SyntaxError: invalid syntax
# >>> 5*3
# 15
# >>> 5*4
# 20
# >>> 5*5
# 25
# >>> 5*6
# 30
# >>> 5*7
# 35
# >>> 5*8
# 40
# >>> 5*9
# 45
# >>> 5*10
# 50
# >>>

# %%
# Install an external module and use it to perform an operation of your interest

import pyttsx3
engine = pyttsx3.init()
engine.say("Do it!! girl.")

engine.runAndWait()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 3
#       1 # Install an external module and use it to perform an operation of your interest
# ----> 3 import pyttsx3
#       4 engine = pyttsx3.init()
#       5 engine.say("Do it!! girl.")
#
# ModuleNotFoundError: No module named 'pyttsx3'

# %%
# Write a python program to print the contents of a directory using the os module. Search online for the function which does that.

import os

def print_directory_contents(path):
    try:
        for item in os.listdir(path):
            print(item)
    except Exception as e:
        print(f"Error: {e}")

# Specify the directory path
directory_path = '/ME'

# Print the contents of the specified directory
print_directory_contents(directory_path)
# Out:
# Error: [Errno 2] No such file or directory: '/ME'

# %%
#import pyjokes

# print("PRINTING JOKES")
#joke = pyjokes.get_joke()
#print(joke)

# """
# SO THANKS
# THAT WAS MY PROGRAM
# ANOTHER LINE YET ANOTHER LINE
# """

print("Hey")
# Out:
# Hey

# %% [markdown]
# CHATPTER -02
# VARIABLES AND DATATYPES

# %%
# Write a python program to add two numbers.
a = 1.2
b = 3.4
c = a+b
print(c)
# Out:
# 4.6

# %%
# Write a python program to find remainder when a number is divided by 2.

number = int(input("Enter a number: "))
remainder = number % 2
print(f"The remainder when {number} is divided by 2 is: {remainder}")
# Out:
# Enter a number: 7
# The remainder when 7 is divided by 2 is: 1

# %%
#Check the type of the variable assigned using input () function.
a = "31.2"
b = float(a) # a but the type should be float
t = type(b)

print(t)
# Out:
# <class 'float'>

# %%
#use Comparison operators to find out whether a given Variable a is greater than b or not. Take a= 34 and b=80
a = 34
b = 80
is_greater = a > b
print(f"Is a ({a}) greater than b ({b})? {is_greater}")
# Out:
# Is a (34) greater than b (80)? False

# %%
#Write a python program to find average of two numbers entered by the user.
a = int(input('Enter a number'))
b = int(input("Enter a number"))
average = a+b /2
print("the average  of two number is:", average)
# Out:
# Enter a number67
# Enter a number87
# the average  of two number is: 110.5

# %%
#Write a python program to calculate square of a number entered by the user.
a = int(input("enter a number"))
square = a*a
print("the square of a number is:", square)
# Out:
# enter a number65
# the square of a number is: 4225

# %% [markdown]
# CHAPTER-03
# STRINGS

# %%
# Write a Python program to display a user entered name followed by Good Aftermoon using input() function.
name = input("Enter the name: ")
print(f"Good Afternoon {name}")
# Out:
# Enter the name: yusuf
# Good Afternoon yusuf

# %%
# Write a program to fill in a letter template given below with name and date
#letter = "Dear <|NAME|>,
#You are selected!
#<|DATE|>"

letter_template = """Dear <|NAME|>,
You are selected!
<|DATE|>"""

user_name = "Alice"
current_date = "16 May 2026"

custom_letter = letter_template.replace("<|NAME|>", user_name)
custom_letter = custom_letter.replace("<|DATE|>", current_date)

print(custom_letter)
# Out:
# Dear Alice,
# You are selected!
# 16 May 2026

# %%
#Write a program to detect double spaces in a String.
name = "I am Good  Writer  "

print(name.find("  "))
# Out:
# 9

# %%
#replace the double space from problem 3 with single spaces.

name = "I am a Good  Writer   "
name = name.replace("  ", " ")

print(name)
# Out:
# I am a Good Writer

# %%
# write a program to format the following letter using escape sequence characters.
#letter = "Dear Harry, This Python Course is nice. Thanks!"
letter = "Dear Harry, \n\t This Python course is nice.\n Thanks!"
print(letter)
# Out:
# Dear Harry,
# 	 This Python course is nice.
#  Thanks!

# %% [markdown]
# CHAPTER-04
# LISTS AND TUPLES

# %%
#write a program to store seven fruits in a list entered by the user.

fruits =[]
f1 = input("Enter fruit Name: ")
fruits.append(f1)
f2 = input("Enter fruit Name: ")
fruits.append(f2)
f3 = input("Enter fruit Name: ")
fruits.append(f3)
f4 = input("Enter fruit Name: ")
fruits.append(f4)
f5 = input("Enter fruit Name: ")
fruits.append(f5)
f6 = input("Enter fruit Name: ")
fruits.append(f6)
f7 = input("Enter fruit Name: ")
fruits.append(f7)

print(fruits)
# Out:
# Enter fruit Name: dragon fruit
# Enter fruit Name: orange
# Enter fruit Name: apple
# Enter fruit Name: banana
# Enter fruit Name: pineapple
# Enter fruit Name: strawberry
# Enter fruit Name: guava
# ['dragon fruit', 'orange', 'apple', 'banana', 'pineapple', 'strawberry', 'guava']

# %%
#write a program to accept marks of 6 students and display them in a sorted manner.

students =[]
s1 = int(input("Enter the marks: "))
students.append(s1)
s2 = int(input("Enter the marks: "))
students.append(s2)
s3 = int(input("Enter the marks: "))
students.append(s3)
s4 = int(input("Enter the marks: "))
students.append(s4)
s5 = int(input("Enter the marks: "))
students.append(s5)
s6 = int(input("Enter fruit Name: "))
students.append(s6)

students.sort()
print(students)
# Out:
# Enter the marks: 67
# Enter the marks: 45
# Enter the marks: 87
# Enter the marks: 23
# Enter the marks: 12
# Enter fruit Name: 55
# [12, 23, 45, 55, 67, 87]

# %%
# Check that a tuple type cannot be changed in python.

a= (34, 234, "windows")

a[2]= "ios"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_9628/3925224469.py in <cell line: 0>()
#       3 a= (34, 234, "windows")
#       4
# ----> 5 a[2]= "ios"
#
# TypeError: 'tuple' object does not support item assignment

# %%
# Write a program to sum a list with 4 numbers.
A = [82, 65, 18, 10 ]

print(sum(A))
# Out:
# 175

# %%
# Write a program to count the number of zeros in the following tuple:

a = (7, 0, 8, 0, 0, 9)

z = a.count(0)
print(z)
# Out:
# 3

# %% [markdown]
# CHAPTER-05
# DICTIONARY & SETS

# %%
#Write a program to create a dictionary of hindi words with values as their english translation. Provide user with an option to look it up.

words = {
    "kaam": "work",
    "kya": "what",
    "sher": "lion",
}

word= input("Enter the word you want meaning of: ")

print(words[word])
# Out:
# Enter the word you want meaning of: sher
# lion

# %%
#write a program to input eight numbers from the user and display all the unique numbers (once).

s = set()
n = input("Enter number: ")
s.add(int(n))
n = input("Enter number: ")
s.add(int(n))
n = input("Enter number: ")
s.add(int(n))
n = input("Enter number: ")
s.add(int(n))
n = input("Enter number: ")
s.add(int(n))
n = input("Enter number: ")
s.add(int(n))
n = input("Enter number: ")
s.add(int(n))
n = input("Enter number: ")
s.add(int(n))

print(s)
# Out:
# Enter number: 44
# Enter number: 77
# Enter number: 56
# Enter number: 55
# Enter number: 76
# Enter number: 55
# Enter number: 77
# Enter number: 34
# {34, 76, 44, 77, 55, 56}

# %%
#Can we have a set with 18(int) and '18'(str) as a value in it?

s= set()
s.add(18)
s.add("18")

print(s)
# Out:
# {18, '18'}

# %%
#what will be the length of following set s:

s= set()
s.add(20)
s.add(20.0)
s.add('20') # length of s after these operations?

print(s)
print(len(s))
# Out:
# {'20', 20}
# 2

# %%
s={}
# what is the type of's'?

print(type(s))
# Out:
# <class 'dict'>

# %%
#Create an empty dictionary. Allow 4 friends to enter their favorite language as value and use key as their names.
# Assume that the names are unique.

A = {}

name= input("Enter friends name: ")
lang= input("Enter language name: ")
A.update({name: lang})

name= input("Enter friends name: ")
lang= input("Enter language name: ")
A.update({name: lang})

name= input("Enter friends name: ")
lang= input("Enter language name: ")
A.update({name: lang})

name= input("Enter friends name: ")
lang= input("Enter language name: ")
A.update({name: lang})

print(A)
# Out:
# Enter friends name: yash
# Enter language name: odisha
# Enter friends name: payal
# Enter language name: lahori
# Enter friends name: rashi
# Enter language name: russian
# Enter friends name: kk
# Enter language name: jj
# {'yash': 'odisha', 'payal': 'lahori', 'rashi': 'russian', 'kk': 'jj'}

# %%
#If the name of 2 friends are same; what will happen to the program in problem 6?
A = {}

name= input("Enter friends name: ")
lang= input("Enter language name: ")
A.update({name: lang})

name= input("Enter friends name: ")
lang= input("Enter language name: ")
A.update({name: lang})

name= input("Enter friends name: ")
lang= input("Enter language name: ")
A.update({name: lang})

name= input("Enter friends name: ")
lang= input("Enter language name: ")
A.update({name: lang})

print(A)
# Out:
# Enter friends name: uu
# Enter language name: oo
# Enter friends name: ss
# Enter language name: ee
# Enter friends name: ss
# Enter language name: ee
# Enter friends name: qq
# Enter language name: ww
# {'uu': 'oo', 'ss': 'ee', 'qq': 'ww'}

# %%
#If language of two friends are same; what will happen to the program in problem 6?
#TODO: ANSWER - no change will occur in this case. the values can be same .

#Create an empty dictionary. Allow 4 friends to enter their favorite language as value and use key as their names.
# Assume that the names are unique.

A = {}

name= input("Enter friends name: ")
lang= input("Enter language name: ")
A.update({name: lang})

name= input("Enter friends name: ")
lang= input("Enter language name: ")
A.update({name: lang})

name= input("Enter friends name: ")
lang= input("Enter language name: ")
A.update({name: lang})

name= input("Enter friends name: ")
lang= input("Enter language name: ")
A.update({name: lang})

print(A)
# Out:
# Enter friends name: sd
# Enter language name: s
# Enter friends name:
# Enter language name:
# Enter friends name:
# Enter language name:
# Enter friends name:
# Enter language name:
# {'sd': 's', '': ''}

# %%
#Can you change the vales inside a list which is contained in set S?

s={8,7,12,"Harry",[1,2]}
#can't include list in a set
#even if it does we cant change by indexing
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_9628/3620711722.py in <cell line: 0>()
#       1 #Can you change the vales inside a list which is contained in set S?
#       2
# ----> 3 s={8,7,12,"Harry",[1,2]}
#       4 #can't include list in a set
#       5 #even if it does we cant change by indexing
#
# TypeError: unhashable type: 'list'
