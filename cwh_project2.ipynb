# %%
#We are going to write a program that generates a random number and asks the user to guess it.
#If the player's guess is higher than the actual number, the program displays " Lower rumber please
#Similarly if the user's guess is too low, the program prints higher number please" Where the user gueses the correct nunber, the program displays the number of guesses the player used to arrive at the number
#Hint: use the random module

# %%
import random
n = random.randint(1, 100)
a = -1
guesses = 0

print("Welcome to the Number Guessing Game!")
while a != n:
    user_input = input("Guess the number (between 1 and 100): ")

    try:
        a = int(user_input)
    except ValueError:
        print("Invalid input! Please enter a whole number.")
        continue

    guesses += 1


    if a > n:
        print("Lower number please ")
    elif a < n:
        print("Higher number please ")
    else:
        print(f"Correct! You guessed it in {guesses} attempts.")
# Out:
# Welcome to the Number Guessing Game!
# Guess the number (between 1 and 100): 45
# Lower number please
# Guess the number (between 1 and 100): 20
# Higher number please
# Guess the number (between 1 and 100): 30
# Lower number please
# Guess the number (between 1 and 100): 25
# Lower number please
# Guess the number (between 1 and 100): 23
# Correct! You guessed it in 5 attempts.
