# %% [markdown]
# CHAPTER-06
# CONDITIONAL EXPRESSIONS

# %%
# Write a program to find greatest of four number entered by user
a=int(input("Enter value of a : "))
b=int(input("Enter value of b: "))
c=int(input("Enter value of c: "))
d=int(input("Enter value of d: "))

if(a>b and a>c and a>d):
    print("a is greatest",a)

elif(b>c and b>a and b>d):
    print("b is greatest.",c)

elif(c>a and c>b and c>d):
    print("c is greatest.",c)

elif(d>a and d>b and d>c):
     print("d is the greatest.",d)

else:
    print("d is the greatest.", d)
# Out:
# Enter value of a : 55
# Enter value of b: 54
# Enter value of c: 33
# Enter value of d: 22
# a is greatest 55

# %%
#Write a program to find out whether a student has passes or failed if it requires a total of 40% and at least 33% in each subject. Assume 3 subjects and take marks as an input from the user.

marks1 = int(input("Enter marks 1: "))
marks2 = int(input("Enter marks 2: "))
marks3 = int(input("Enter marks 3: "))

total_percentage =(100*(marks1 + marks2 + marks3))/300

if(total_percentage >= 40 and marks1>=33 and marks2>=33 and marks3>=33):
    print("PASS.", total_percentage)

else:
    print("FAIL.",total_percentage)
# Out:
# Enter marks 1: 54
# Enter marks 2: 43
# Enter marks 3: 44
# PASS. 47.0

# %%
# A spam comment is defined as a text containing following keywords:“Make a lot of money”, “buy now”, “subscribe this”, “click this”. Write a program to detect these spams.

p= "Make a lot of money"
q= "buy now"
r= "subscribe this"
s= "click this"

message = input("Enter comment: ")

if((p in message) or (q in message) or (r in message) or (s in message)):
    print("This is a Spam.")

else:
    print("This is not a Spam.")
# Out:
# Enter comment: buy bnow
# This is not a Spam.

# %%
#Write a program to find whether a given username contains less than 10 characters or not.

user_name= input("Enter username: ")

if(len(user_name)<10):
    print("The username contains less than 10 characters.")
else:
    print("The username contains more than 10 characters.")
# Out:
# Enter username: devyanichaudhary
# The username contains more than 10 characters.

# %%
#Write a program which finds out whether a given name is present in a list or not.

list =["simran", 'ananya', "james", "harry", "drogo"]

name = input("Enter name: ")

if(name in list ):
    print("name is present in list.")
else:
    print("name is not present in list.")
# Out:
# Enter name: ananya
# name is present in list.

# %%
#Write a program to calculate the grade of a student from his marks from the following scheme:
# 90 – 100 = Ex
# 80 – 90 = A
# 70 – 80 = B
# 60 – 70 = C
# 50 – 60 = D
# <50 = F

marks = int(input("Enter the marks: "))

if marks > 100 or marks < 0:
     print("Invalid marks. Please enter a value between 0 and 100.")

elif marks >= 90:
     print("Grade is Excellent.")

elif marks >= 80:
     print("Grade is A.")

elif marks >= 70:
     print("Grade is B.")

elif marks >= 60:
     print("Grade is C.")

elif marks >= 50:
     print("Grade is D.")

else:
     print("Grade is F.")
# Out:
# Enter the marks: 56
# Grade is D.

# %%
#Write a program to find out whether a given post is talking about "harry" or not ?

post = input("Enter the post: ")

if("Devyani".lower() in post.lower()):
    print("This post is talking about Devyani.")
else:
    print("This post is not talking about Devyani.")
# Out:
# Enter the post: devyani is writing code
# This post is talking about Devyani.

# %% [markdown]
# CHAPTER-07
# LOOPS

# %%
#Write a program to print multiplication table of a given number using for loop.

n = int(input("Enter number: "))

for i in range(1,11):
    print(f"{n} x {i} = {n*i} ")
# Out:
# Enter number: 56
# 56 x 1 = 56
# 56 x 2 = 112
# 56 x 3 = 168
# 56 x 4 = 224
# 56 x 5 = 280
# 56 x 6 = 336
# 56 x 7 = 392
# 56 x 8 = 448
# 56 x 9 = 504
# 56 x 10 = 560

# %%
#Write a program to greet all the person names stored in a list l1 and which starts with S.

l1 = ["Harry", "Soham", "Sachin", "Rahul"]

for name in l1:
    if(name.startswith("S")):
        print(f"hello {name}")
# Out:
# hello Soham
# hello Sachin

# %%
#Attempt problem 1 using while loop.
n = int(input("Enter number: "))

i =1
while(i<11):
    print(f"{n} x {i} = {n*i}")
    i +=1
# Out:
# Enter number: 44
# 44 x 1 = 44
# 44 x 2 = 88
# 44 x 3 = 132
# 44 x 4 = 176
# 44 x 5 = 220
# 44 x 6 = 264
# 44 x 7 = 308
# 44 x 8 = 352
# 44 x 9 = 396
# 44 x 10 = 440

# %%
#Write a program to find whether a given number is prime or not.

n = int(input("Enter number: "))

for i in range(2,n):
    if(n%i) ==0:
        print("not prime")
        break
else:
    print("prime")
# Out:
# Enter number: 4
# not prime

# %%
#Write a program to find the sum of first n natural numbers using while loop.

n = int(input("Enter the number: "))

i =0
sum =0
while(i<=n):
    sum = sum + i
    i +=1

print(sum)
# Out:
# Enter the number: 14
# 105

# %%
# Write a program to calculate the factorial of a given number using for loop.

n = int(input("Enter value of n: "))
product = 1

for i in range(1,n+1):
    product =  product * i

print(f"Factorial of {n} is {product}")
# Out:
# Enter value of n: 6
# Factorial of 6 is 720

# %%
# Write a program to print the following star pattern.
#   *
#  ***
# ***** for n = 3

n = int(input("Enter value of n: "))

for i in range (1, n+1):
    print(" "* (n-i), end="")
    print("*"* (2*i-1),  end="")
    print("")
# Out:
# Enter value of n: 3
#   *
#  ***
# *****

# %%
#Write a program to print the following star pattern:
#*
#**
#***
n = int(input("Enter the value: "))

for i in range (1, n+1):
    print("*"* (i), end="")
    print("")
# Out:
# Enter the value: 4
# *
# **
# ***
# ****

# %%
# Write a program to print the following star pattern.
# ***
# * * for n = 3
# ***

n = int(input("Enter the number: "))

for i in range (1,n+1):
    if( i==1 or i ==n):
        print("*"* n, end="")
    else:
        print("*", end="")
        print(" "* (n-2), end="")
        print("*", end="")
    print("")
# Out:
# Enter the number: 6
# ******
# *    *
# *    *
# *    *
# *    *
# ******

# %%
#Write a program to print multiplication table of n using for loops in reversed order.

n = int(input("Enter number: "))

for i in range(1,11):
    print(f"{n} x {11-i} = {n*(11-i)} ")
# Out:
# Enter the number: 15
# 15 x 10 = 150
# 15 x 9 = 135
# 15 x 8 = 120
# 15 x 7 = 105
# 15 x 6 = 90
# 15 x 5 = 75
# 15 x 4 = 60
# 15 x 3 = 45
# 15 x 2 = 30
# 15 x 1 = 15

# %% [markdown]
# CHAPTER-08 FUNCTIONS AND RECURSIONS

# %%
# Write a program using functions to find greatest of three numbers.

def greatest(a, b, c):
    if(a>b and a>c):
        return a
    elif(b>a and b>c):
        return b
    elif(c>b and c>a):
        return c

a = 56
b = 37
c = 89

print(greatest(a, b, c))
# Out:
# 89

# %%
#Write a python program using function to convert Celsius to Fahrenheit.

def fah_to_cel(f):
    return 5*(f-32)/9

f = float(input("Enter temperature in F: "))
c = fah_to_cel(f)
print(f"{round(c, 2)} °C")
# Out:
# Enter temperature in F: 108
# 42.22 °C

# %%
#How do you prevent a python print() function to print a new line at the end.

print("a")
print("b")
print("c", end="")
print("d", end=""),
# Out:
# a
# b
# cd
# (None,)

# %%
#Write a recursive function to calculate the sum of first n natural numbers.

def sum(n):
    if(n==1):
        return 1
    return sum(n-1) + n

print(sum(9))
# Out:
# 45

# %%
#Write a python function to print first n lines of the following pattern:
# ***
# ** - for n = 3
# *

def pattern(n):
    if(n==0):
        return
    print("*" * n)
    pattern(n-1)


pattern(3)
# Out:
# ***
# **
# *

# %%
#Write a python function which converts inches to cms.

def in_to_cms(inch):
    return inch * 2.54

n = int(input("Enter value in inches: "))

print(f"The corresponding value in cms is {in_to_cms(n)}")
# Out:
# Enter value in inches: 7
# The corresponding value in cms is 17.78

# %%
#Write a python function to remove a given word from a list and strip it at the same time.
def remove_and_strip(words, word_to_remove):
    result = []

    for item in words:
        stripped_item = item.strip()

        if stripped_item != word_to_remove:
            result.append(stripped_item)

    return result

my_list = ["  Harry  ", "Rohan", "  Shubham ", "Harry", "Divya  "]

print(remove_and_strip(my_list, "Harry"))
# Out:
# ['Rohan', 'Shubham', 'Divya']

# %%
#Write a python function to print multiplication table of a given number.

def multiply(n):
    for i in range(1, 11):
        print(f"{n} X {i} = {n*i}")

multiply(5)
# Out:
# 5 X 1 = 5
# 5 X 2 = 10
# 5 X 3 = 15
# 5 X 4 = 20
# 5 X 5 = 25
# 5 X 6 = 30
# 5 X 7 = 35
# 5 X 8 = 40
# 5 X 9 = 45
# 5 X 10 = 50
